# %%
import json

items = []
with open("/Users/iramkamdar/RAG/data/generated_email_pairs.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        items.append(json.loads(line))

# %%
with open("/Users/iramkamdar/RAG/data/generated_email_pairs.json", "w", encoding="utf-8") as f:
    json.dump(items, f, indent=2, ensure_ascii=False)
